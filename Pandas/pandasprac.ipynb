# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.3

# %%
# Series
dp = pd.Series([2, 4, 6])

print(dp)
print(dp.loc[1])

# %%
#filtering
print(dp>=4)

# %%
#Data Frame
students={"Name":["Guna","gopi"],
          "age":[20,25]}
ds = pd.DataFrame(students)
print(ds.loc[0])

# %%
#File Handling
da=pd.read_csv("customers.csv")
print(da.head())
print(da.to_string())
print(da["City"])

# %%
#Aggregate
print(dp.max)
print(dp.min)
print(dp.sum)
print(dp.median)
